# %% [markdown]
# # NaiveBayes Classifier

# %% [markdown]
# This project is implemntation of naivebayes algorithm for text classification.

# %% [markdown]
# A dataset of users comment on an onlion store is given. Our goal is to use naivebayes to analyze their comment's seniment and predict whether the user will recommend that product or not.Steps we are going to take are as follows:<br>
# 1. Dataset Preparation: The first step is the Dataset Preparation step which includes the process of loading a dataset and performing basic pre-processing. The dataset is then splitted into train and validation sets.
# 2. Feature Engineering: The next step is the Feature Engineering in which the raw dataset is transformed into flat features which can be used in a machine learning model. This step also includes the process of creating new features from the existing data.
# 3. Model Training: The final step is the Model Building step in which a machine learning model is trained on a labelled dataset.

# %%
import numpy as np
import pandas as pd
from hazm import *
import re
import string
import random
from collections import Counter

# %% [markdown]
# A file of stopwords is loaded below for future processings.This file is from Kharazi/Persian-Stopwords[1].

# %%
#stop_words = [re.sub(r'\u200c','',line.rstrip('\n')) for line in open('stop_words.txt',mode="r", encoding="utf-8")]
stop_words = stopwords_list()

# %% [markdown]
# A train and a test dataset is given from digikala which is a e-commerce company.

# %%
test = pd.read_csv('comment_test.csv')
train = pd.read_csv('comment_train.csv')

# %%
train
# Out:
#                       title  \
# 0          زیبا اما کم دوام
# 1                بسیار عالی
# 2                      سلام
# 3         به درد نمیخورهههه
# 4                   کلمن آب
# ...                     ...
# 5995             جنسش عالیه
# 5996             خرید محصول
# 5997                  تعریف
# 5998     اصلا چای ماچا نیسش
# 5999  یک هدست بدون سیم عالی
#
#                                                 comment        recommend
# 0     با وجود سابقه خوبی که از برند ایرانی نهرین سرا...  not_recommended
# 1                                            بسیار عالی      recommended
# 2     من الان ۳ هفته هست استفاده میکنم\r\nبرای کسایی...  not_recommended
# 3     عمرش کمه تا یه هفته بیشتر نمیشه استفاده کرد یا...  not_recommended
# 4     فکر کنین کلمن بخرین با ذوق. کلی پولشو بدین. به...  not_recommended
# ...                                                 ...              ...
# 5995  خیلی جنس پارچش نرم ولطیفه خیلیم جنسش خوبه اما ...      recommended
# 5996  سلام.واقعا فکر نمی کردم به این راحتی اصلاح کنم...      recommended
# 5997  من از دیجی کالا خریدم خیلی زود دستم رسید،زیبا،...      recommended
# 5998  یا شرکت نمیدونسته چای ماچا امپریال چیه یا واقع...  not_recommended
# 5999  این هدست را چند هفته قبل از سایت دیجی کالا خری...      recommended
#
# [6000 rows x 3 columns]

# %% [markdown]
# comment column of the dataset is going to be used in future ,for simplicity.<br>
# In order to train our classifier, we need to transform our headlines of words into numbers, since algorithms only know how to work with numbers.Below there are two functions one for preprocessing and cleaning the data and the other one to create a list of features in which number of occurance of each word is stored.

# %%
def cleanText(text):
    normalizer = Normalizer()
    #stemer = Stemmer()
    #text = stemer.stem(text)
    #lemmantiz = Lemmatizer()
    #text = lemmantiz.lemmatize(text)
    text = normalizer.normalize(text)
    text = re.sub(r'(\u200c)*','',text)
    text = re.sub(r'(\r)*','',text)
    text = re.sub(r'\d+', '', text)
    text = re.sub(r'[A-Za-z]+', '', text)
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\s\s*',' ',text)
    for word in stop_words: 
        text = text.replace(' ' + word + ' ', ' ') 
    return text

def bag_of_words(document,unique_words):
    #construction of the bag of words matrix
    number_of_documents = len(document)
    number_of_words = len(unique_words)
    bag_of_words  = np.zeros((number_of_documents, number_of_words))
    for i in range(number_of_documents):
        for j in range(number_of_words):
            bag_of_words[i, j] = document[i].count(unique_words[j])
    return bag_of_words

# %% [markdown]
# In the CleanText function two stemmer and lemmatizer are used.Both of them return root of the word while Stemming follows an algorithm with steps to perform on the words which makes it faster than Lemmatizer.Since many verbs and words have the same root I was expecting a better performane when using one of these techniques,However,results did not demonstrate any improvments.

# %% [markdown]
# In this problem we want to calssify a comment based on its features so we have to calculate P(recommend|features).So first P(feature|recommend) and P(feature|not_recommend) ,and then P(recommend) and P(not_recommend) must be computed.<br>
# Posterior = P(recommend|features) and P(recommend|features)<br>
# Liklihood = P(feature|recommend) and P(feature|not_recommend)<br>
# Priore = P(recommend) and P(not_recommend)<br>
# Evidence = P(features)

# %%
class MultinomialNB(object):
    def __init__(self, alpha=1.0):
        self.alpha = alpha

    def fit(self, X, y):
        # group by class
        separated = [[x for x, t in zip(X, y) if t == c] for c in np.unique(y)]
        count_sample = X.shape[0]
        self.class_log_prior_ = [np.log(len(i) / count_sample) for i in separated] #P(c)
        count = np.array([np.array(i).sum(axis=0) for i in separated]) + self.alpha
        self.feature_log_prob_ = np.log(count / count.sum(axis=1)[np.newaxis].T) #P(x|c)
        
    def predict_prob(self,X):
        return [(self.feature_log_prob_ * x).sum(axis=1) + self.class_log_prior_ for x in X]
    
    def predict(self,X):
        return np.argmax(self.predict_prob(X), axis=1)

class NaiveBayes(object):
    def __init__(self, alpha=0.0):
        self.alpha = alpha

    def fit(self, X, y):
        # group by class
        separated = [[x for x, t in zip(X, y) if t == c] for c in np.unique(y)]
        count_sample = X.shape[0]
        self.class_prior_ = [np.round(len(i) / count_sample,5) for i in separated] #P(c)
        count = np.array([np.array(i).sum(axis=0) for i in separated]) + self.alpha
        self.feature_prob_ = np.round(count / count.sum(axis=1)[np.newaxis].T,5) #P(x|c)
        
    def predict_prob(self,X):
        return [(self.feature_prob_ * x).sum(axis=1) + self.class_prior_ for x in X]
    
    def predict(self,X):
        return np.argmax(self.predict_prob(X), axis=1)

# %% [markdown]
#  In above implementation Log probability is used to avoid floating point underflow and alpha is used for additive smoothing.Whenever a word does not appear in a comment, the whole probability of either recommend or not_recommend is going to be zero and all other words will have no impact on the result.Therefore,additive smoothing is used to overcome this problem.<br>P(a very good product | not_recomend ) = P(a | not_recomend) x P(very | not_recomend) x P(good | not_recomend) x P(product | not_recomend)

# %% [markdown]
# In additive smoothing a constant(alpha) will be added to the numerator of each features probability in order to prevent them from being zero.<br>

# %%
def precision(TP,TN,FP,FN):
    return TP / (TP + FP)
def recall(TP,TN,FP,FN):
    return TP / (TP + FN)
def F1(precision,recall):
    return (2*precision*recall)/(precision+recall)
def Accuracy(TP,TN,FP,FN):
    return (TP + TN)/(TP + TN + FP + FN)

# %% [markdown]
# None of the precision or recall are sufficient to analyze the resuly of a model.In a case which the model only predicts one comment being recommendeed and that comment is recommended,but it did not predict all the other recommended comments; precision is 100% but the model is not at all a good one.On the other hand, in a scenario which a model predict all comments as recommended, it reaches the recall of 100% but none of the not_recommended comments were ditected.<br>
# We use F1 score which is a harmonic mean of precision and recall and gives a better measure of the incorrectly classified cases than the Accuracy Metric.Moreover, it penalizes the extreme values.

# %% [markdown]
# ## Preprocessing + Additive Smoothing

# %%
x_train = list(map(lambda x: cleanText(x),train['comment']))
x_test = list(map(lambda x: cleanText(x),test['comment']))

# %%
unique_words = list()
for sentence in x_train:
    tokens = word_tokenize(sentence)
    for token in tokens:
        if token not in unique_words:
            unique_words.append(token)

# %%
bag_of_words_train = bag_of_words(x_train,unique_words)
bag_of_words_test = bag_of_words(x_test,unique_words)

# %%
X_train = pd.DataFrame(bag_of_words_train)
X_test = pd.DataFrame(bag_of_words_test)

# %%
# y_train = train['recommend']
# y_test = test['recommend']
y_train = train['recommend'].astype('category').cat.codes
y_test = test['recommend'].astype('category').cat.codes

# %%
model = MultinomialNB()
model.fit(X_train.to_numpy(),y_train.to_numpy())
y= model.predict(X_test.to_numpy())
df_confusion = pd.crosstab(y_test, y)
FN = df_confusion[0][1]
TN = df_confusion[0][0]
TP = df_confusion[1][1]
FP = df_confusion[1][0]
preci = precision(TP,TN,FP,FN)
recal = recall(TP,TN,FP,FN)
print("Accuracy :  %f" % (Accuracy(TP,TN,FP,FN)))
print("Precision :  %f" % (preci))
print("Recall :  %f" % (recal))
print("F1 :  %f" % (F1(preci,recal)))
wron_id =  [i for i in range(len(y_test)) if y_test[i] != y[i]]
# Out:
# Accuracy :  0.887500
# Precision :  0.878049
# Recall :  0.900000
# F1 :  0.888889

# %% [markdown]
# ## Only Additive smoothing

# %%
x_train = list(train['comment'])
x_test = list(test['comment'])

unique_words = list()
for sentence in x_train:
    tokens = word_tokenize(sentence)
    for token in tokens:
        if token not in unique_words:
            unique_words.append(token)

bag_of_words_train = bag_of_words(x_train,unique_words)
bag_of_words_test = bag_of_words(x_test,unique_words)

X_train = pd.DataFrame(bag_of_words_train)
X_test = pd.DataFrame(bag_of_words_test)

y_train = train['recommend'].astype('category').cat.codes
y_test = test['recommend'].astype('category').cat.codes

model = MultinomialNB(alpha=1)
model.fit(X_train.to_numpy(),y_train.to_numpy())
y= model.predict(X_test.to_numpy())
df_confusion = pd.crosstab(y_test, y)
FN = df_confusion[0][1]
TN = df_confusion[0][0]
TP = df_confusion[1][1]
FP = df_confusion[1][0]
preci = precision(TP,TN,FP,FN)
recal = recall(TP,TN,FP,FN)
print("Accuracy :  %f" % (Accuracy(TP,TN,FP,FN)))
print("Precision :  %f" % (preci))
print("Recall :  %f" % (recal))
print("F1 :  %f" % (F1(preci,recal)))
# Out:
# Accuracy :  0.885000
# Precision :  0.871981
# Recall :  0.902500
# F1 :  0.886978

# %% [markdown]
# ## Only Preprocessing

# %%
x_train = list(map(lambda x: cleanText(x),train['comment']))
x_test = list(map(lambda x: cleanText(x),test['comment']))

unique_words = list()
for sentence in x_train:
    tokens = word_tokenize(sentence)
    for token in tokens:
        if token not in unique_words:
            unique_words.append(token)

bag_of_words_train = bag_of_words(x_train,unique_words)
bag_of_words_test = bag_of_words(x_test,unique_words)

X_train = pd.DataFrame(bag_of_words_train)
X_test = pd.DataFrame(bag_of_words_test)

y_train = train['recommend'].astype('category').cat.codes
y_test = test['recommend'].astype('category').cat.codes

model = NaiveBayes(alpha=0)
model.fit(X_train.to_numpy(),y_train.to_numpy())
y= model.predict(X_test.to_numpy())
df_confusion = pd.crosstab(y_test, y)
FN = df_confusion[0][1]
TN = df_confusion[0][0]
TP = df_confusion[1][1]
FP = df_confusion[1][0]
preci = precision(TP,TN,FP,FN)
recal = recall(TP,TN,FP,FN)
print("Accuracy :  %f" % (Accuracy(TP,TN,FP,FN)))
print("Precision :  %f" % (preci))
print("Recall :  %f" % (recal))
print("F1 :  %f" % (F1(preci,recal)))
# Out:
# Accuracy :  0.641250
# Precision :  0.591870
# Recall :  0.910000
# F1 :  0.717241

# %% [markdown]
# ## Neither preprocessing nor additive smoothing

# %%
x_train = list(train['comment'])
x_test = list(test['comment'])

unique_words = list()
for sentence in x_train:
    tokens = word_tokenize(sentence)
    for token in tokens:
        if token not in unique_words:
            unique_words.append(token)
            
bag_of_words_train = bag_of_words(x_train,unique_words)
bag_of_words_test = bag_of_words(x_test,unique_words)

X_train = pd.DataFrame(bag_of_words_train)
X_test = pd.DataFrame(bag_of_words_test)

y_train = train['recommend'].astype('category').cat.codes
y_test = test['recommend'].astype('category').cat.codes

model = NaiveBayes(alpha=0)
model.fit(X_train.to_numpy(),y_train.to_numpy())
y= model.predict(X_test.to_numpy())
df_confusion = pd.crosstab(y_test, y)
FN = df_confusion[0][1]
TN = df_confusion[0][0]
TP = df_confusion[1][1]
FP = df_confusion[1][0]
preci = precision(TP,TN,FP,FN)
recal = recall(TP,TN,FP,FN)
print("Accuracy :  %f" % (Accuracy(TP,TN,FP,FN)))
print("Precision :  %f" % (preci))
print("Recall :  %f" % (recal))
print("F1 :  %f" % (F1(preci,recal)))
# Out:
# Accuracy :  0.682500
# Precision :  0.633212
# Recall :  0.867500
# F1 :  0.732068

# %% [markdown]
# | preprocess/smoothing | Accuracy | Precision | Recall | F1|
# | --- | --- | --- | --- | --- |
# | preprocess+smoothing | 0.88 | 0.87 | 0.90 | 0.88|
# | preprocess| 0.64 | 0.59 | 0.91 | 0.71|
# | Addittive smoothing | 0.88 | 0.87 | 0.90 | 0.88|
# | None | 0.68 | 0.63 | 0.86 | 0.73|

# %% [markdown]
# Addittive smoothing greatly improves the accuracy of the model,while preprocessing does not seem that helpful.preprocessing slightly improves recall of the model meaning that it correctly predict more recommended comments.The value 1 for recall means that no non-recommended comment is wrongly labeled as recomended.

# %%
for i in range(len(wron_id)):
    print(i)
    print(test.iloc[i])
    print('---------------------')
# Out:
# 0
# title                                                  وری گود
# comment      تازه خریدم یه مدت کار بکنه مشخص میشه کیفیت قطعاتش
# recommend                                          recommended
# Name: 0, dtype: object
# ---------------------
# 1
# title         زیاد مناسب نیست رنگ پس میده یه وقتایی موقع نوشتن
# comment      با این قیمت گزینه های بهتری هم میشه گرفت.\r\nر...
# recommend                                      not_recommended
# Name: 1, dtype: object
# ---------------------
# 2
# title                                                پنکه گوشی
# comment      خیلی عالیه، فقط کاش از اون سمتش میشد به پاوربا...
# recommend                                          recommended
# Name: 2, dtype: object
# ---------------------
# 3
# title                                         دستگاه خیلی ضعیف
# comment      من این فیس براس چند روز یپش به دستم رسید و الا...
# recommend                                      not_recommended
# Name: 3, dtype: object
# ---------------------
# 4
# title                                              عالی و بیست
# comment      بنده یه هارد اکسترنال دارم که کابل فابریکش سال...
# recommend                                          recommended
# Name: 4, dtype: object
# ---------------------
# 5
# title                                     خوب ولی کارایی محدود
# comment      مدل 46MM به دست شما نخواهد رسید و به جای آن مد...
# recommend                                      not_recommended
# Name: 5, dtype: object
# ---------------------
# 6
# title                                   کیفیت پاک کنندگی پایین
# comment      پایه نگهدارنده برای ۲۰۶ ندارد و قدرت پاک کنندگ...
# recommend                                      not_recommended
# Name: 6, dtype: object
# ---------------------
# 7
# title                                      اصلا پیشنهاد نمیکنم
# comment      محصول بی کیفیت . زمان تماس که اصلا صدای واضحی ...
# recommend                                      not_recommended
# Name: 7, dtype: object
# ---------------------
# 8
# title                                           نقد پس از خرید
# comment      سلام ، راحت شدم از کابل شارژ ، توصیه میشود به ...
# recommend                                          recommended
# Name: 8, dtype: object
# ---------------------
# 9
# title                                         ریش تراش نامناسب
# comment      من وقتی میخواستم خرید کنم نظرات رو خوندم ولی ب...
# recommend                                      not_recommended
# Name: 9, dtype: object
# ---------------------
# 10
# title                                            بی نهایت نازک
# comment      نوشته سفری اما دیگه فکر نمیکردم در این حد نازک...
# recommend                                      not_recommended
# Name: 10, dtype: object
# ---------------------
# 11
# title                           کیف دوشی
# comment      واقعا دوسش دارم جنسشم عالیه
# recommend                    recommended
# Name: 11, dtype: object
# ---------------------
# 12
# title                                                    mi 4w
# comment      کاور مقاوم و قشنگیه اما متأسفانه مدت زیادیه که...
# recommend                                      not_recommended
# Name: 12, dtype: object
# ---------------------
# 13
# title                                           بعد از تست اره
# comment      کلید ضامن پلاستیکی و بی کیفیت.\r\nیه گیر توی ب...
# recommend                                      not_recommended
# Name: 13, dtype: object
# ---------------------
# 14
# title                                              کیفیت پایین
# comment      حتی به عنوان میکروسکوپ دانش آموزی هم ارزش ندار...
# recommend                                      not_recommended
# Name: 14, dtype: object
# ---------------------
# 15
# title                                              گزینه خوبیه
# comment      سلام ، گزینه خوبیه من یه mg2540  خریده بودم یع...
# recommend                                          recommended
# Name: 15, dtype: object
# ---------------------
# 16
# title                                               ساعت اسکمی
# comment      من این ساعت رو لز دیجی کالا خریدم ازش راضیم گا...
# recommend                                          recommended
# Name: 16, dtype: object
# ---------------------
# 17
# title                                   تستر پرادا کندی فلورال
# comment      من این ادو تویلتو خریدم \r\nبر خلاف اینکه نوشت...
# recommend                                          recommended
# Name: 17, dtype: object
# ---------------------
# 18
# title                                              نقد منصفانه
# comment      من تو تخفیف ویژه 5 تا خریدم و همشون رو هم تست ...
# recommend                                      not_recommended
# Name: 18, dtype: object
# ---------------------
# 19
# title                                            خیالم راحت شد
# comment      فندک قبلیم مدام فیوز میسوزوند و یک بار شارژر م...
# recommend                                          recommended
# Name: 19, dtype: object
# ---------------------
# 20
# title                                            خیلی بی کیفیت
# comment      اصلا اون چیزی که انتظار داشتم نبود اصلا مقاوم ...
# recommend                                      not_recommended
# Name: 20, dtype: object
# ---------------------
# 21
# title                       بسیار خوشبو
# comment      پیشنهاد میکنم... خوشبووووو
# recommend                   recommended
# Name: 21, dtype: object
# ---------------------
# 22
# title                                            پول دور ریختن
# comment      من قبلا با توجه به نزدیک بودن رایحه این عطر به...
# recommend                                      not_recommended
# Name: 22, dtype: object
# ---------------------
# 23
# title                                    در یک کلام فوق العاده
# comment      من این روکش رو روی ال ۹۰ بستم کیفیتش فوق العاد...
# recommend                                          recommended
# Name: 23, dtype: object
# ---------------------
# 24
# title                                  یه کوله سبک و جمع و جور
# comment      کالا کاملا اصالت داره و از طریق بارکدخوان متوج...
# recommend                                          recommended
# Name: 24, dtype: object
# ---------------------
# 25
# title                                         خراب بودن سیستمی
# comment      من خریدم خوب وصل میشه و سرعتش عالیه ولی اصلا ب...
# recommend                                      not_recommended
# Name: 25, dtype: object
# ---------------------
# 26
# title                                                کیفیت صفر
# comment      اصلا انتظار همچین جنس بی کیفیتی رو نداشتم، چند...
# recommend                                      not_recommended
# Name: 26, dtype: object
# ---------------------
# 27
# title                                                 کت مناسب
# comment      برای پسرم تهیه کردم خیلی قشنگه دوخت عالی داره ...
# recommend                                          recommended
# Name: 27, dtype: object
# ---------------------
# 28
# title                                          محصول ضعیفی هست
# comment      بدون پخش بو و ماندگاری زیاد امیدوارم کیفیتش رو...
# recommend                                      not_recommended
# Name: 28, dtype: object
# ---------------------
# 29
# title                                              ظروف مویلار
# comment      نظر قبلیمو تصحیح میکنم بعد از مدتی استفاده لکه...
# recommend                                      not_recommended
# Name: 29, dtype: object
# ---------------------
# 30
# title                                                    اشبیت
# comment      این ظرف برای کوه نوردان، شکارچیان وافرادی که ب...
# recommend                                          recommended
# Name: 30, dtype: object
# ---------------------
# 31
# title            ساعت زیبا با طراحی و ظاهر دقیق ، قیمت مناسب .
# comment      خیلی زیبا ،عالی ، قیمت خوب ظاهر زیبا ، جنس موا...
# recommend                                          recommended
# Name: 31, dtype: object
# ---------------------
# 32
# title                                              کفش چرم ژاو
# comment      دوباره تکرار میکنم که از لحاظ کیفیت وشیک و راح...
# recommend                                          recommended
# Name: 32, dtype: object
# ---------------------
# 33
# title               ضخیم هست
# comment         بدرد نمیخوره
# recommend    not_recommended
# Name: 33, dtype: object
# ---------------------
# 34
# title                                                چیز خوبیه
# comment      بخرید.چیز خوبیه.یه موقع احتیاج میشه بودش بهتر ...
# recommend                                          recommended
# Name: 34, dtype: object
# ---------------------
# 35
# title                                                     وحید
# comment      وقتی ازجعبه خارج کردم، متوجه شدم از ۲ناحیه شکس...
# recommend                                      not_recommended
# Name: 35, dtype: object
# ---------------------
# 36
# title                                   قابل قبول هست
# comment      به اندازه پولی که داده میشه کاربردی هست.
# recommend                                 recommended
# Name: 36, dtype: object
# ---------------------
# 37
# title                                               هرگز نخرید
# comment      فشار زیاد به دست\r\nمدت زمان اندازه گیری فشار\...
# recommend                                      not_recommended
# Name: 37, dtype: object
# ---------------------
# 38
# title                                            درکل خوب نیست
# comment      من گرفتم تا هفته اول خوب بود بعدش یه هفته سیم ...
# recommend                                      not_recommended
# Name: 38, dtype: object
# ---------------------
# 39
# title                                        نسبت به قیمت خوبه
# comment      من خریدم ولی حس میکنم کنترلش مثل دلفینی ها راح...
# recommend                                          recommended
# Name: 39, dtype: object
# ---------------------
# 40
# title                                  عالی حرف نداره بخریدش
# comment      به غیر از اینکه خیلی کوچولو هستش ولی خیلی عالیه
# recommend                                        recommended
# Name: 40, dtype: object
# ---------------------
# 41
# title                خرید 2 عدد و مغایرت سریaو bو تفاوت دو مدل
# comment      ، دوستان عزیز دقت کنند در مورد خرید این پاوربا...
# recommend                                      not_recommended
# Name: 41, dtype: object
# ---------------------
# 42
# title                                       نخرید خوب نیس اصلا
# comment      با سلام، با چیزی که توی عکس هس فرق داره، اصلا ...
# recommend                                      not_recommended
# Name: 42, dtype: object
# ---------------------
# 43
# title        به هیچ عنوان ارزش خرید نداره
# comment      به هیچ عنوان ارزش خرید نداره
# recommend                 not_recommended
# Name: 43, dtype: object
# ---------------------
# 44
# title                                                  خیلی بد
# comment      پایه ها شل\r\nقفلش خوب نگه نمیداره\r\nپیچش پلا...
# recommend                                      not_recommended
# Name: 44, dtype: object
# ---------------------
# 45
# title                              عالی ولی دارای یه نکته جالب
# comment      محاسبه شاخص های سلامتی و ظرافت در عین محکمی و ...
# recommend                                          recommended
# Name: 45, dtype: object
# ---------------------
# 46
# title                                              کیفیت پایین
# comment      اتصال پایه هاش خیلی ضعیفه.وقتی بازش کردم یکی ا...
# recommend                                      not_recommended
# Name: 46, dtype: object
# ---------------------
# 47
# title                  ظاهری زیبا و باطنی نا ارام و فوق العاده
# comment      سلام\r\n حدود یک ماهه که این هدفون و برای من ک...
# recommend                                          recommended
# Name: 47, dtype: object
# ---------------------
# 48
# title                                            عروسک پشمی سگ
# comment      خیلی دوستش دارد ۲ سایز کوچک و بزرگش را برای دخ...
# recommend                                          recommended
# Name: 48, dtype: object
# ---------------------
# 49
# title                                                چراغ خواب
# comment      اگر میخواید پشه ها کبابتون کن و توی نور این حش...
# recommend                                      not_recommended
# Name: 49, dtype: object
# ---------------------
# 50
# title                                             ga20ریش تراش
# comment      ریش تراش خوب و سبک و خوش دست و دارای قدرت مناس...
# recommend                                          recommended
# Name: 50, dtype: object
# ---------------------
# 51
# title                                        عالی و ظاهری زیبا
# comment      تازه به دستم رسید ظاهر زیبایی داره از خریدم را...
# recommend                                          recommended
# Name: 51, dtype: object
# ---------------------
# 52
# title                                           واقعا بدون نقص
# comment      من سالهاست مشتری دیجی کالان اما اولین باره نظر...
# recommend                                          recommended
# Name: 52, dtype: object
# ---------------------
# 53
# title                                کفشی معمولی با قیمت متوسط
# comment      نسبت به پولی که میدید اصلا انتظار اینکه وقتی ب...
# recommend                                      not_recommended
# Name: 53, dtype: object
# ---------------------
# 54
# title                      پشیمان از خرید این اسباب بازی
# comment      واقعا"با این محصول دیجی کالا زیر سوال میره.
# recommend                                not_recommended
# Name: 54, dtype: object
# ---------------------
# 55
# title                                            بسیار نامرغوب
# comment      کیفیت چرم بسیار پایین بود.وجود زدگی و پوسیدگی ...
# recommend                                      not_recommended
# Name: 55, dtype: object
# ---------------------
# 56
# title                                             جنس و زیبایی
# comment      زیبا هستش از مدل های دیگه مثل پارس ... بنظرم ز...
# recommend                                          recommended
# Name: 56, dtype: object
# ---------------------
# 57
# title                                   زیبا و با کیفیت
# comment      در حد متوسط هدفون بسیار عالی و اقتصادی است
# recommend                                   recommended
# Name: 57, dtype: object
# ---------------------
# 58
# title                                               برند بخرید
# comment      جنسش به هیچ وجه کروم وانادیوم نیست بسیار نرمه ...
# recommend                                      not_recommended
# Name: 58, dtype: object
# ---------------------
# 59
# title                           برا داخل خونه فقط پیشنهاد میدم
# comment      اصلا باتصویرش نمیخونه خیلی کوچیک تره \r\nاز ری...
# recommend                                      not_recommended
# Name: 59, dtype: object
# ---------------------
# 60
# title                                                کیسه چرمی
# comment      در کل از خرید خودم راضی هستم،حدود 4 ماه میشه ا...
# recommend                                          recommended
# Name: 60, dtype: object
# ---------------------
# 61
# title                                              کتری و قوری
# comment      من این محصول رو. تو پیشنهاد ویژه خریداری کردم ...
# recommend                                      not_recommended
# Name: 61, dtype: object
# ---------------------
# 62
# title                                              شارژر همراه
# comment      چند ماهه به دستم رسیده وکاملا ازش راضی هستم خی...
# recommend                                          recommended
# Name: 62, dtype: object
# ---------------------
# 63
# title                                                کاهش قیمت
# comment      حالا که گرون گرون خریدم انقدر قیمتهارو کاهش دا...
# recommend                                          recommended
# Name: 63, dtype: object
# ---------------------
# 64
# title                     دریل خوب و با کیفیت
# comment      حتما پیشنهاد میکنم پشیمون نمیشید
# recommend                         recommended
# Name: 64, dtype: object
# ---------------------
# 65
# title        خیلی عالیه باتریشم اصلا زود خالی نمیشه بهترین ...
# comment      خیلی عالیه باتریشم اصلا زود خالی نمیشه بهترین ...
# recommend                                          recommended
# Name: 65, dtype: object
# ---------------------
# 66
# title                                              اندازه کوچک
# comment      اندازه کوچیک ینی به دکمه ها فشار وارد میکنه مج...
# recommend                                      not_recommended
# Name: 66, dtype: object
# ---------------------
# 67
# title                کاهش زیاد سرعت
# comment      وحشتناک سرعتو کم میکنه
# recommend           not_recommended
# Name: 67, dtype: object
# ---------------------
# 68
# title                                                    زودپز
# comment      خیلی خوبه الان چند باری هست داریم استفاده میکن...
# recommend                                          recommended
# Name: 68, dtype: object
# ---------------------
# 69
# title                                        بررسی فیلتر سرکان
# comment      من خودم جزو افرادی بودم که نزدیک سیزده ساله از...
# recommend                                      not_recommended
# Name: 69, dtype: object
# ---------------------
# 70
# title                             عالی بود
# comment      عالی. بود بهترین. صدا رو داره
# recommend                      recommended
# Name: 70, dtype: object
# ---------------------
# 71
# title                     مناسب برای ورزش های تخصصی و غیرتخصصی
# comment      برای ورزشهای معمولی و حرفه ای میشه ازش به راحت...
# recommend                                          recommended
# Name: 71, dtype: object
# ---------------------
# 72
# title                                                  دوام کم
# comment      من خریدم اما متاسفانه به دو هفته نرسید که زنجی...
# recommend                                      not_recommended
# Name: 72, dtype: object
# ---------------------
# 73
# title                                            دستکش بدنسازی
# comment      با دومین استفاده در باشگاه لاستیک روی مفصل انگ...
# recommend                                      not_recommended
# Name: 73, dtype: object
# ---------------------
# 74
# title                    عالی نسبت ب هزینه ای ک میکنید
# comment      ماشین کار راه اندازی ب نسبت قیمتش می ارزه
# recommend                                  recommended
# Name: 74, dtype: object
# ---------------------
# 75
# title                                     کل صفحه رو نمیپوشونه
# comment      جنسش و چسبندگیش عالیه اما کل صفحه رو نمیپوشونه...
# recommend                                      not_recommended
# Name: 75, dtype: object
# ---------------------
# 76
# title                                                  راضی ام
# comment      چیبندگی خوبی داره و رول بزرگ بود و من فک میکرد...
# recommend                                          recommended
# Name: 76, dtype: object
# ---------------------
# 77
# title                                              پخش بو عالی
# comment      بوی خوب و قابل قبولی داره . پخش بوی خیلی خوبی ...
# recommend                                          recommended
# Name: 77, dtype: object
# ---------------------
# 78
# title                                              خیلی بد است
# comment      درخواست مرجوع کردن کاسترو دارم خیلی بده ظرفیتش...
# recommend                                      not_recommended
# Name: 78, dtype: object
# ---------------------
# 79
# title                                  یکی از بهترین های بازار
# comment      من این مودم را حدود ۱ سال و نیم پیش خریدم از ن...
# recommend                                          recommended
# Name: 79, dtype: object
# ---------------------
# 80
# title                                         تجربه ای یک ساله
# comment      با سلام خدمت همه دوستان\r\nتجربه یک ساله خرید ...
# recommend                                          recommended
# Name: 80, dtype: object
# ---------------------
# 81
# title                                                روغن عالی
# comment      روغن ایگل ایشالا که کره ای باشه من راضیم برای ...
# recommend                                          recommended
# Name: 81, dtype: object
# ---------------------
# 82
# title                          کند شارژ می کنه
# comment      چون کند شارژ می کنه بدرد نمی خوره
# recommend                      not_recommended
# Name: 82, dtype: object
# ---------------------
# 83
# title                                   چراغ چک موتور خاموش شد
# comment      سلام دوستان بعد از استفاده چراغ چک تویوتا کمری...
# recommend                                          recommended
# Name: 83, dtype: object
# ---------------------
# 84
# title                                        افتضاح یکبار مصرف
# comment      من قبلا نظر مثبت نسبت به این محصول رو دادم و خ...
# recommend                                      not_recommended
# Name: 84, dtype: object
# ---------------------
# 85
# title                 اسپینر
# comment      مزخرفه\r\nنخرید
# recommend    not_recommended
# Name: 85, dtype: object
# ---------------------
# 86
# title                 عدم کارایی به خاطر زاویه دید بسیار محدود
# comment      بر خلاف متن ادعایی زاویه دید این دوربین ۱۷۰ در...
# recommend                                      not_recommended
# Name: 86, dtype: object
# ---------------------
# 87
# title                                               راضی نبودم
# comment      خیلی جنس ضعیفی داره و نسبت ب قیمتش اصلا ارزش خ...
# recommend                                      not_recommended
# Name: 87, dtype: object
# ---------------------
# 88
# title        خیلی خیلی خیلی خوبه و عالیه و خوشگل و کارای دا...
# comment                                            خداییش خوبه
# recommend                                          recommended
# Name: 88, dtype: object
# ---------------------
# 89
# title                                              کار نمی کند
# comment      بعد از مدتی قفل باز نشد و کلید قابلیت چرخش خود...
# recommend                                      not_recommended
# Name: 89, dtype: object
# ---------------------
# 90
# title                                           بعد از استفاده
# comment      خیلی خوب و مقاوم هست و طراحی زیبایی داره\r\nفق...
# recommend                                          recommended
# Name: 90, dtype: object
# ---------------------
# 91
# title                                  نسبت به قیمتش خیلی خوبه
# comment      شکل قشنگی داره ، میکروفونش کنار دهان قرار میگی...
# recommend                                          recommended
# Name: 91, dtype: object
# ---------------------
# 92
# title                                  باطری خراب
# comment      باطریش مشکل داشت مرجوع شد که بیاد...
# recommend                         not_recommended
# Name: 92, dtype: object
# ---------------------
# 93
# title                      کیفیت
# comment      فقط نخرید بدرد نخور
# recommend        not_recommended
# Name: 93, dtype: object
# ---------------------
# 94
# title                                               طول عمر کم
# comment      این مدل برخلاف بسته بندی مطلوبی که داره ولی با...
# recommend                                      not_recommended
# Name: 94, dtype: object
# ---------------------

# %% [markdown]
# Using n-gram in preprocessing might improve the accuracy since many combinations of words have the exact opposite of looking at them seperately.<br>
# Using titles as well as comments might help as well.

# %% [markdown]
# References<br>
# GitHub. 2020. Kharazi/Persian-Stopwords. [online] Available at: <https://github.com/kharazi/persian-stopwords> [Accessed 18 November 2020].
#
# Kenzo's Blog. 2020. Naive Bayes From Scratch In Python. [online] Available at: <http://kenzotakahashi.github.io/naive-bayes-from-scratch-in-python.html> [Accessed 21 November 2020].
